# %% [markdown]
# # MOVIE RATING PREDICTION WITH PYTHON

# %%
import pandas as pd

# %%
df_movie=pd.read_csv(r'C:\Users\sobia\Downloads\archive (30)\IMDB-Movie-Data.csv')

# %%
df_movie
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# ## Going to follow these phases
# - explore data analysis
# - preprocessing
# - feature engineering
# - machine learning modeling techniques.
# (Build a model that predicts the rating of a movie based on
# features like genre, director, and actors. You can use regression
# techniques to tackle this problem.)

# %% [markdown]
# # - Data Preprocessing

# %%
df_movie
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df_movie.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
df_movie['Metascore'].mean()
# Out:
# 58.98504273504273

# %%
df_movie['Metascore'].fillna(59, inplace = True)

# %%
df_movie['Metascore'].isnull().sum()
# Out:
# 0

# %%
df_movie.drop(['Revenue (Millions)'], axis = 1, inplace = True)

# %%
df_movie
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rank               1000 non-null   int64
#  1   Title              1000 non-null   object
#  2   Genre              1000 non-null   object
#  3   Description        1000 non-null   object
#  4   Director           1000 non-null   object
#  5   Actors             1000 non-null   object
#  6   Year               1000 non-null   int64
#  7   Runtime (Minutes)  1000 non-null   int64
#  8   Rating             1000 non-null   float64
#  9   Votes              1000 non-null   int64
#  10  Metascore          1000 non-null   float64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 86.1+ KB

# %%
df_movie['Genre']
# Out:
# 0       Action,Adventure,Sci-Fi
# 1      Adventure,Mystery,Sci-Fi
# 2               Horror,Thriller
# 3       Animation,Comedy,Family
# 4      Action,Adventure,Fantasy
#                  ...
# 995         Crime,Drama,Mystery
# 996                      Horror
# 997         Drama,Music,Romance
# 998            Adventure,Comedy
# 999       Comedy,Family,Fantasy
# Name: Genre, Length: 1000, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

df_movie['Genre_encoded'] = label_encoder.fit_transform(df_movie['Genre'])

# %%
df_movie
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df_movie['Director']
# Out:
# 0                James Gunn
# 1              Ridley Scott
# 2        M. Night Shyamalan
# 3      Christophe Lourdelet
# 4                David Ayer
#                ...
# 995               Billy Ray
# 996                Eli Roth
# 997              Jon M. Chu
# 998          Scot Armstrong
# 999        Barry Sonnenfeld
# Name: Director, Length: 1000, dtype: object

# %%
df_movie['Director_encoded'] = label_encoder.fit_transform(df_movie['Director'])

# %%
df_movie
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df_movie['Actors']
# Out:
# 0      Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# 1      Noomi Rapace, Logan Marshall-Green, Michael Fa...
# 2      James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# 3      Matthew McConaughey,Reese Witherspoon, Seth Ma...
# 4      Will Smith, Jared Leto, Margot Robbie, Viola D...
#                              ...
# 995    Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...
# 996    Lauren German, Heather Matarazzo, Bijou Philli...
# 997    Robert Hoffman, Briana Evigan, Cassie Ventura,...
# 998    Adam Pally, T.J. Miller, Thomas Middleditch,Sh...
# 999    Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...
# Name: Actors, Length: 1000, dtype: object

# %%
df_movie['Actors_encoded'] = label_encoder.fit_transform(df_movie['Actors'])

# %%
df_movie
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df_movie['Metascore']
# Out:
# 0      76.0
# 1      65.0
# 2      62.0
# 3      59.0
# 4      40.0
#        ...
# 995    45.0
# 996    46.0
# 997    50.0
# 998    22.0
# 999    11.0
# Name: Metascore, Length: 1000, dtype: float64

# %%
df_movie['Metascore']=df_movie['Metascore'].astype(int)

# %%
df_movie['Metascore']
# Out:
# 0      76
# 1      65
# 2      62
# 3      59
# 4      40
#        ..
# 995    45
# 996    46
# 997    50
# 998    22
# 999    11
# Name: Metascore, Length: 1000, dtype: int32

# %%
df_movie['Rating']=df_movie['Rating'].astype(int)

# %%
df_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rank               1000 non-null   int64
#  1   Title              1000 non-null   object
#  2   Genre              1000 non-null   object
#  3   Description        1000 non-null   object
#  4   Director           1000 non-null   object
#  5   Actors             1000 non-null   object
#  6   Year               1000 non-null   int64
#  7   Runtime (Minutes)  1000 non-null   int64
#  8   Rating             1000 non-null   int32
#  9   Votes              1000 non-null   int64
#  10  Metascore          1000 non-null   int32
#  11  Genre_encoded      1000 non-null   int32
#  12  Director_encoded   1000 non-null   int32
#  13  Actors_encoded     1000 non-null   int32
# dtypes: int32(5), int64(4), object(5)
# memory usage: 90.0+ KB

# %%
df_movie.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.282000  1.698083e+05
# std     288.819436     3.205962          18.810908     1.001738  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.000000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.000000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.000000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.000000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#          Metascore  Genre_encoded  Director_encoded  Actors_encoded
# count  1000.000000     1000.00000       1000.000000     1000.000000
# mean     58.986000      100.91400        327.299000      497.423000
# ...

# %%
df_movie.corr()
# Out:
#                        Rank      Year  Runtime (Minutes)    Rating     Votes  \
# Rank               1.000000 -0.261605          -0.221739 -0.227085 -0.283876
# Year              -0.261605  1.000000          -0.164900 -0.197239 -0.411904
# Runtime (Minutes) -0.221739 -0.164900           1.000000  0.382023  0.407062
# Rating            -0.227085 -0.197239           0.382023  1.000000  0.500236
# Votes             -0.283876 -0.411904           0.407062  0.500236  1.000000
# Metascore         -0.185153 -0.076074           0.202235  0.581960  0.318092
# Genre_encoded      0.154346  0.037264          -0.164095 -0.002330 -0.255765
# Director_encoded   0.016420 -0.014787           0.010960 -0.006044 -0.012850
# Actors_encoded     0.091752 -0.061880          -0.071584 -0.008896 -0.011970
#
#                    Metascore  Genre_encoded  Director_encoded  Actors_encoded
# Rank               -0.185153       0.154346          0.016420        0.091752
# ...

# %% [markdown]
# # - Exploratory Data Analysis EDA

# %%
df_movie.shape
# Out:
# (1000, 14)

# %%
df_movie.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Metascore', 'Genre_encoded',
#        'Director_encoded', 'Actors_encoded'],
#       dtype='object')

# %% [markdown]
# ### understand data columns

# %% [markdown]
# - Rank : it shows the movie rank
# - Title : it shows the title of movie
# - Genre : it shows the genre or catagory of movie
# - Description : it shows the summary or storyline of movie
# - Director : it shows movie director
# - Actors : it shows the movie actors names
# - Year : it shows the year when movie was released
# - Runtime (Minutes) : it shows the duration of movie in minutes
# - Rating : it shows users rating to the movie
# - Votes : it shows number of votes movie has recieved
# - Revenue (Millions) : it shows revenue earned by movie in millions
# - Metascore : it shows metascore of movie

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15, 10))
sns.countplot(x='Year' , data=df_movie, palette = 'PuBuGn_r')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='count'>

# %%
df_movie
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
sns.countplot(x='Rating' , data=df_movie, palette = 'PuBuGn_r')
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='count'>

# %%
df_movie.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Metascore', 'Genre_encoded',
#        'Director_encoded', 'Actors_encoded'],
#       dtype='object')

# %%
df_movie['Rank']
# Out:
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5
#        ...
# 995     996
# 996     997
# 997     998
# 998     999
# 999    1000
# Name: Rank, Length: 1000, dtype: int64

# %%
sns.barplot(x='Year', y='Votes', data=df_movie)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Votes'>

# %%
sns.barplot(x='Year', y='Metascore', data=df_movie)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Metascore'>

# %% [markdown]
# # - Feature Engineering

# %%
df_movie
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
feature_columns = [11,12,13]

X = df_movie.iloc[:, feature_columns]

# %%
X
# Out:
#      Genre_encoded  Director_encoded  Actors_encoded
# 0               11               265             184
# 1               85               518             736
# 2              195               391             418
# 3               92               105             658
# 4                7               136             971
# ..             ...               ...             ...
# 995            144                69             160
# 996            190               176             574
# 997            170               324             794
# 998             61               549              12
# 999            121                59             550
#
# [1000 rows x 3 columns]

# %%
targeted_column = [8]
y = df_movie.iloc[:, targeted_column]

# %%
y
# Out:
#      Rating
# 0         8
# 1         7
# 2         7
# 3         7
# 4         6
# ..      ...
# 995       6
# 996       5
# 997       6
# 998       5
# 999       5
#
# [1000 rows x 1 columns]

# %% [markdown]
# # - Machine Learning

# %%
from sklearn.model_selection import train_test_split

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(
    X, y, test_size=0.20, random_state=0)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(Xtrain, ytrain)
# Out:
# LinearRegression()

# %%
model.fit(Xtest, ytest)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([[-0.00017831,  0.00035836, -0.00036681]])

# %%
model.intercept_
# Out:
# array([6.35745237])

# %%
y_pred = model.predict(Xtest)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
# model evaluation
print(
  'mean_squared_error : ', mean_squared_error(ytest, y_pred))
print(
  'mean_absolute_error : ', mean_absolute_error(ytest, y_pred))
# Out:
# mean_squared_error :  0.754804844074496
# mean_absolute_error :  0.696040603743957
